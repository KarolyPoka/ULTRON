# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import glob
import random
import os, sys

# %%
#in this section we will demonstrate a few samples from the training set
#we are not using labels because we are working with mixed dataset for GANs

folder = "Dokumentumok/celeba/train/" ##path to the training images
images = os.listdir(folder)

demonstrate = random.sample(images, 10)

i = 0

for image in demonstrate:
    plt.subplot(2,5,i+1)
    im = plt.imread(folder+image)
    IM = im
    i+=1
    imgplot = plt.imshow(im)
    
    

plt.show()

# %%
#A few samples from the TonyStark dataset.

folder = "Dokumentumok/tony/" ##path to the training images
images_tony = os.listdir(folder)

demonstrate = random.sample(images_tony, 10)

i = 0

for image in demonstrate:
    plt.subplot(2,5,i+1)   
    im = Image.open(folder+image)
    i+=1
    plt.axis('off')
    imgplot = plt.imshow(im)

plt.show()
